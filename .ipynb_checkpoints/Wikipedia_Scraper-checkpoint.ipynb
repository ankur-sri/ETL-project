# %% [markdown]
# #### Disclaimer:  We do not own or claim ownership of Wikipedia or any of the information we have sourced from it.  We highly appreciate the work independent contributors have made and will use it responsibly.

# %%
import pandas as pd
import re
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Scraping Wikipedia with Pandas

# %%
# Let's first grab the tables
wiki_link = "https://en.wikipedia.org/wiki/List_of_best-selling_game_consoles"
consoles_sold = pd.read_html(wiki_link)
print(f"We found {len(consoles_sold)} tables.")
# Out:
# We found 7 tables.

# %%
# Now let's Find the largest one
largest_index = 0

try:
    for i in range(len(consoles_sold)):
        if consoles_sold[i].count().max() > consoles_sold[largest_index].count().max():
            largest_index = i
    print(f"The largest table we grabbed is table {largest_index + 1}.  It has a size of {consoles_sold[largest_index].count().max()}.")
except KeyError:
    print(f"We already found the largest table.  It has a size of {consoles_sold.count().max()} rows.")
# Out:
# The largest table we grabbed is table 1.  It has a size of 40.

# %%
# Now to create the pandas DataFrame
try:
    consoles_sold = consoles_sold[largest_index]
    print("Converted the table successfully into a DataFrame.")
except KeyError:
    print("We already converted the table into a DataFrame.")
# Out:
# Converted the table successfully into a DataFrame.

# %%
# Save the data to a csv
try:
    print(pd.read_csv("Wiki_Scrape_clean.csv").head(3))
except:
    consoles_sold.to_csv("Wiki_Scrape_clean.csv")
# Out:
#         Platform      Firm  Date Released (Year AD)  Units sold (million)  \
# 0  PlayStation 2      Sony                     2000                 155.0
# 1    Nintendo DS  Nintendo                     2004                 154.0
# 2       Game Boy  Nintendo                     1989                 119.0
#
#   Estimate
# 0      NaN
# 1      NaN
# 2      NaN

# %% [markdown]
# # The DataFrame Table:

# %%
consoles_sold = pd.read_csv("Wiki_Scrape_clean.csv")
consoles_sold.head()
# Out:
#         Platform      Firm  Date Released (Year AD)  Units sold (million)  \
# 0  PlayStation 2      Sony                     2000                 155.0
# 1    Nintendo DS  Nintendo                     2004                 154.0
# 2       Game Boy  Nintendo                     1989                 119.0
# 3  PlayStation 4      Sony                     2013                 110.0
# 4    PlayStation      Sony                     1994                 102.0
#
#   Estimate
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN

# %%
platforms_wiki = consoles_sold['Platform']
platforms_wiki
# Out:
# 0                           PlayStation 2
# 1                             Nintendo DS
# 2                                Game Boy
# 3                           PlayStation 4
# 4                             PlayStation
# 5                                     Wii
# 6                           PlayStation 3
# 7                                Xbox 360
# 8                        Game Boy Advance
# 9                    PlayStation Portable
# 10                           Nintendo 3DS
# 11          Nintendo Entertainment System
# 12                        Nintendo Switch
# 13    Super Nintendo Entertainment System
# 14                              Xbox One
# 15                           Sega Genesis
# 16                            Nintendo 64
# 17                             Atari 2600
# 18                                   Xbox
# 19                               GameCube
# 20                                   WiiU
# 21                         Sega Game Gear
# 22                       PlayStation Vita
# 23                          Master System
# 24                          TurboGrafx-16
# 25                            Sega Saturn
# 26                              Dreamcast
# 27              Super NES Classic Edition
# 28                              Sega Pico
# 29                             WonderSwan
# 30                          Color TV-Game
# 31                          Intellivision
# 32                                 N-Gage
# 33                    NES Classic Edition
# 34                           ColecoVision
# 35                       Magnavox Odyssey
# 36                             Atari Lynx
# 37                           Philips CD-i
# 38                                Telstar
# 39                             Atari 5200
# Name: Platform, dtype: object

# %% [markdown]
# ### Now grab the content from the other video games sheet

# %%
the_other_table = pd.read_csv('Video_Games.csv')
the_other_table.head()
# Out:
#                        Name Platform  Year_of_Release         Genre Publisher  \
# 0                Wii Sports      Wii           2006.0        Sports  Nintendo
# 1         Super Mario Bros.      NES           1985.0      Platform  Nintendo
# 2            Mario Kart Wii      Wii           2008.0        Racing  Nintendo
# 3         Wii Sports Resort      Wii           2009.0        Sports  Nintendo
# 4  Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  Critic_Score  \
# 0     41.36     28.96      3.77         8.45         82.53          76.0
# 1     29.08      3.58      6.81         0.77         40.24           NaN
# 2     15.68     12.76      3.79         3.29         35.52          82.0
# 3     15.61     10.93      3.28         2.95         32.77          80.0
# 4     11.27      8.89     10.22         1.00         31.37           NaN
#
#    Critic_Count User_Score  User_Count Developer Rating
# 0          51.0          8       322.0  Nintendo      E
# 1           NaN        NaN         NaN       NaN    NaN
# 2          73.0        8.3       709.0  Nintendo      E
# 3          73.0          8       192.0  Nintendo      E
# 4           NaN        NaN         NaN       NaN    NaN

# %%
platforms_base = []

for console in the_other_table['Platform']:
    if console not in platforms_base:
        platforms_base.append(console)

for code in platforms_base:
    print(code)
# Out:
# Wii
# NES
# GB
# DS
# X360
# PS3
# PS2
# SNES
# GBA
# PS4
# 3DS
# N64
# PS
# XB
# PC
# 2600
# PSP
# XOne
# WiiU
# GC
# GEN
# DC
# PSV
# SAT
# SCD
# WS
# NG
# TG16
# 3DO
# GG
# PCFX

# %%
sorted_set = {}

for console in platforms_wiki:
    if console in platforms_base:
        sorted_set[console] = console
    else:
        found = False
        if ("Sega" in console):
            # Sega ones
            console_Acronym_Check = re.sub("Sega| ", "", console)

            if re.search("Saturn|Genesis", console_Acronym_Check):
                console_Acronym_Check = console_Acronym_Check[0:3].upper()
            else:
                console_Acronym_Check = re.sub("[a-z ,#]", "", console_Acronym_Check)
        elif "Xbox" == console:
            # Lazy Xbox one
            sorted_set[console] = "XB"
            continue
        elif "DS" in console:
            # Lazy DS one
            if "3" in console:
                sorted_set[console] = "3DS"
            else:
                sorted_set[console] = "DS"
            continue
        elif "Game Boy" in console:
            # Game boy lazy
            if "Advance" in console:
                sorted_set[console] = "GBA"
            else:
                sorted_set[console] = "GB"
            continue
        elif "NES" in console:
            if "Super NES" in console:
                sorted_set[console] = "SNES"
            else:
                sorted_set[console] = "NES"
        else:
            # The rest
            console_Acronym_Check = re.sub("[a-z ,#]|Atari", "", console)

        for toy in platforms_base:
            toy_Acronym_Check = re.sub("[a-z ,#]", "", toy)

            if (console_Acronym_Check == toy_Acronym_Check) and re.search(toy, console):
                found = True
                break
            elif (console_Acronym_Check == toy_Acronym_Check):
                found = True
                break

        if found:
            sorted_set[console] = toy
        else:
            print(f"Don't have {console}; '{console_Acronym_Check}' doesn't match")
# Out:
# Don't have Nintendo Switch; 'NS' doesn't match
# Don't have Master System; 'MS' doesn't match
# Don't have TurboGrafx-16; 'TG-16' doesn't match
# Don't have Dreamcast; 'D' doesn't match
# Don't have Super NES Classic Edition; 'D' doesn't match
# Don't have Sega Pico; 'P' doesn't match
# Don't have Color TV-Game; 'CTV-G' doesn't match
# Don't have Intellivision; 'I' doesn't match
# Don't have N-Gage; 'N-G' doesn't match
# Don't have NES Classic Edition; 'N-G' doesn't match
# Don't have ColecoVision; 'CV' doesn't match
# Don't have Magnavox Odyssey; 'MO' doesn't match
# Don't have Atari Lynx; 'L' doesn't match
# Don't have Philips CD-i; 'PCD-' doesn't match
# Don't have Telstar; 'T' doesn't match
# Don't have Atari 5200; '5200' doesn't match

# %%
for i in range (len(platforms_wiki)):
    try:
        consoles_sold['Platform'][i] = sorted_set[platforms_wiki[i]]
    except KeyError:
        print(f"Key '{platforms_wiki[i]}' DNE")
# Out:
# Key 'Nintendo Switch' DNE
# Key 'Master System' DNE
# Key 'TurboGrafx-16' DNE
# Key 'Dreamcast' DNE
# Key 'Sega Pico' DNE
# Key 'Color TV-Game' DNE
# Key 'Intellivision' DNE
# Key 'N-Gage' DNE
# Key 'ColecoVision' DNE
# Key 'Magnavox Odyssey' DNE
# Key 'Atari Lynx' DNE
# Key 'Philips CD-i' DNE
# Key 'Telstar' DNE
# Key 'Atari 5200' DNE
# C:\Users\sriva\anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
consoles_sold.head(13)
# Out:
#            Platform       Firm  Date Released (Year AD)  Units sold (million)  \
# 0               PS2       Sony                     2000                 155.0
# 1                DS   Nintendo                     2004                 154.0
# 2                GB   Nintendo                     1989                 119.0
# 3               PS4       Sony                     2013                 110.0
# 4                PS       Sony                     1994                 102.0
# 5               Wii   Nintendo                     2006                 102.0
# 6               PS3       Sony                     2006                  87.0
# 7              X360  Microsoft                     2005                  54.0
# 8               GBA   Nintendo                     2001                  82.0
# 9               PSP       Sony                     2004                  81.0
# 10              3DS   Nintendo                     2011                  76.0
# 11              NES   Nintendo                     1983                  62.0
# 12  Nintendo Switch   Nintendo                     2017                  56.0
#
#     Estimate
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
# 5        NaN
# 6        NaN
# 7        NaN
# 8        NaN
# 9   estimate
# 10       NaN
# 11       NaN
# 12       NaN

# %%
try:
    consoles_sold = consoles_sold.drop(columns=['Estimate'])
except KeyError:
    print("Dropped it already; like Skrillex")

for row in consoles_sold.index:
    if consoles_sold['Platform'][row] not in platforms_base:
        consoles_sold = consoles_sold.drop([row])

# %%
consoles_sold.index = consoles_sold['Platform']
consoles_sold = consoles_sold.drop(columns=['Platform'])
consoles_sold.head(13)
# Out:
#                Firm  Date Released (Year AD)  Units sold (million)
# Platform
# PS2            Sony                     2000                 155.0
# DS         Nintendo                     2004                 154.0
# GB         Nintendo                     1989                 119.0
# PS4            Sony                     2013                 110.0
# PS             Sony                     1994                 102.0
# Wii        Nintendo                     2006                 102.0
# PS3            Sony                     2006                  87.0
# X360      Microsoft                     2005                  54.0
# GBA        Nintendo                     2001                  82.0
# PSP            Sony                     2004                  81.0
# 3DS        Nintendo                     2011                  76.0
# NES        Nintendo                     1983                  62.0
# SNES       Nintendo                     1990                  49.0

# %%
console_agg_pd = the_other_table.groupby(['Platform']).sum()
console_agg_pd.head()
# Out:
#           Year_of_Release  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# Platform
# 2600             229928.0     90.60      5.47      0.00         0.91
# 3DO                5984.0      0.00      0.00      0.10         0.00
# 3DS             1030721.0     83.49     61.48    100.67        13.36
# DC               103997.0      5.43      1.69      8.56         0.27
# DS              4261381.0    382.67    188.89    175.57        59.28
#
#           Global_Sales  Critic_Score  Critic_Count  User_Count
# Platform
# 2600             97.08           0.0           0.0         0.0
# 3DO               0.10           0.0           0.0         0.0
# 3DS             259.09       11273.0        5069.0     16041.0
# DC               15.97        1223.0         247.0      1183.0
# DS              807.10       45717.0       13364.0     15764.0

# %%
console_agg_pd = console_agg_pd.drop(columns=['Year_of_Release'])

# %%
console_agg_pd.head()
# Out:
#           NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  \
# Platform
# 2600         90.60      5.47      0.00         0.91         97.08
# 3DO           0.00      0.00      0.10         0.00          0.10
# 3DS          83.49     61.48    100.67        13.36        259.09
# DC            5.43      1.69      8.56         0.27         15.97
# DS          382.67    188.89    175.57        59.28        807.10
#
#           Critic_Score  Critic_Count  User_Count
# Platform
# 2600               0.0           0.0         0.0
# 3DO                0.0           0.0         0.0
# 3DS            11273.0        5069.0     16041.0
# DC              1223.0         247.0      1183.0
# DS             45717.0       13364.0     15764.0

# %%
merged_df = pd.merge(console_agg_pd, consoles_sold, how='inner', on=['Platform'])
merged_df = merged_df.drop(columns=['Critic_Score', 'Critic_Count', 'User_Count'])

# %%
merged_df = merged_df.rename(columns ={"Units sold (million)": "Units_Sold"})
merged_df
# Out:
#           NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales       Firm  \
# Platform
# 2600         90.60      5.47      0.00         0.91         97.08      Atari
# 3DS          83.49     61.48    100.67        13.36        259.09   Nintendo
# DS          382.67    188.89    175.57        59.28        807.10   Nintendo
# GB          114.32     47.82     85.12         8.20        255.45   Nintendo
# GBA         187.54     75.25     47.33         7.73        318.50   Nintendo
# GC          133.46     38.71     21.58         5.18        199.36   Nintendo
# GEN          21.05      6.05      2.70         0.97         30.78       Sega
# GG            0.00      0.00      0.04         0.00          0.04       Sega
# N64         139.02     41.06     34.22         4.38        218.88   Nintendo
# NES         125.94     21.15     98.65         5.31        251.07   Nintendo
# NES         125.94     21.15     98.65         5.31        251.07   Nintendo
# PS          336.52    213.61    139.82        40.91        730.68       Sony
# PS2         583.84    339.29    139.20       193.44       1255.64       Sony
# PS3         393.49    330.29     80.19       135.68        939.43       Sony
# PS4         108.74    141.09     16.00        48.35        314.23       Sony
# PSP         109.17     66.68     76.78        41.42        294.30       Sony
# PSV          12.58     13.12     21.93         6.46         54.12       Sony
# SAT           0.72      0.54     32.26         0.07         33.59       Sega
# SNES         61.23     19.04    116.55         3.22        200.05   Nintendo
# SNES         61.23     19.04    116.55         3.22        200.05   Nintendo
# WS            0.00      0.00      1.42         0.00          1.42     Bandai
# Wii         496.90    262.21     69.33        79.07        908.13   Nintendo
# WiiU         38.10     25.13     13.01         5.95         82.16   Nintendo
# X360        602.47    270.76     12.43        85.76        971.63  Microsoft
# XB          186.69     60.95      1.38         8.72        258.26  Microsoft
# XOne         93.12     51.59      0.34        14.27        159.44  Microsoft
#
#           Date Released (Year AD)  Units_Sold
# Platform
# 2600                         1977        30.0
# 3DS                          2011        76.0
# DS                           2004       154.0
# GB                           1989       119.0
# GBA                          2001        82.0
# GC                           2001        22.0
# GEN                          1988        35.0
# GG                           1990        11.0
# N64                          1996        34.0
# NES                          1983        62.0
# NES                          2016         3.0
# PS                           1994       102.0
# PS2                          2000       155.0
# PS3                          2006        87.0
# PS4                          2013       110.0
# PSP                          2004        81.0
# PSV                          2011        12.0
# SAT                          1994         9.0
# SNES                         1990        49.0
# SNES                         2017         5.0
# WS                           1999         3.5
# Wii                          2006       102.0
# WiiU                         2012        14.0
# X360                         2005        54.0
# XB                           2001        24.0
# XOne                         2013        47.0

# %%
plt.subplots(figsize=(12,9))
ax = sns.barplot(x=merged_df.index , y=merged_df.Units_Sold)
ax.set_title('Total Number of Consoles Sold', size=25)
ax.set_ylabel('Number Sold (millions)', size=25)
ax.set_xlabel('Console', size=25)
# Out:
# Text(0.5, 0, 'Console')
